# %%
import numpy as np
import pandas as pd

# %%
csv_data_path = 'https://raw.githubusercontent.com/turingplanet/pandas-intro/main/public-datasets/small_survey_results.csv'
survey_df = pd.read_csv(csv_data_path) 
survey_df
# Out:
#      Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0         20900  I am a developer by profession      Yes   NaN         10
# 1         28235  I am a developer by profession       No  45.0         10
# 2         26082  I am a developer by profession      Yes  23.0         14
# 3         19890  I am a developer by profession      Yes  61.0         21
# 4         16393  I am a developer by profession      Yes  25.0         15
# ..          ...                             ...      ...   ...        ...
# 995       51360  I am a developer by profession      Yes  26.0         13
# 996       16771  I am a developer by profession      Yes   NaN         11
# 997       38831  I am a developer by profession      Yes   NaN        NaN
# 998        7093  I am a developer by profession      Yes   NaN        NaN
# 999       51843  I am a developer by profession      Yes  29.0         20
#
#     CompFreq  CompTotal  ConvertedComp        Country          CurrencyDesc  \
# 0    Monthly     8000.0        53040.0       Bulgaria         Bulgarian lev
# 1    Monthly   670000.0       867480.0         Norway       Norwegian krone
# 2     Yearly    65000.0        65000.0  United States  United States dollar
# 3        NaN        NaN            NaN         Canada       Canadian dollar
# 4     Weekly        NaN            NaN        Uruguay        Uruguayan peso
# ..       ...        ...            ...            ...                   ...
# 995  Monthly    16000.0        12312.0          Egypt        Egyptian pound
# 996      NaN        NaN            NaN  United States  United States dollar
# 997      NaN        NaN            NaN    Netherlands                   NaN
# 998      NaN        NaN            NaN      Indonesia     Indonesian rupiah
# 999  Monthly    90000.0        10680.0          Kenya       Kenyan shilling
#
#      ...                  SurveyEase           SurveyLength Trans  \
# 0    ...                         NaN                    NaN    No
# 1    ...                        Easy  Appropriate in length    No
# 2    ...                        Easy  Appropriate in length    No
# 3    ...                        Easy  Appropriate in length   NaN
# 4    ...                        Easy  Appropriate in length    No
# ..   ...                         ...                    ...   ...
# 995  ...  Neither easy nor difficult  Appropriate in length    No
# 996  ...                         NaN                    NaN   NaN
# 997  ...                         NaN                    NaN   NaN
# 998  ...                         NaN                    NaN   NaN
# 999  ...                        Easy  Appropriate in length    No
#
#                                         UndergradMajor  \
# 0    Computer science, computer engineering, or sof...
# 1    Computer science, computer engineering, or sof...
# 2    Computer science, computer engineering, or sof...
# 3    Another engineering discipline (such as civil,...
# 4    Another engineering discipline (such as civil,...
# ..                                                 ...
# 995  Another engineering discipline (such as civil,...
# 996  Another engineering discipline (such as civil,...
# 997                                                NaN
# 998                                                NaN
# 999  Information systems, information technology, o...
#
#                 WebframeDesireNextYear  \
# 0                                  NaN
# 1                                  NaN
# 2                ASP.NET Core;React.js
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 995                   Express;React.js
# 996             Angular;Express;Spring
# 997                                NaN
# 998                                NaN
# 999  Angular;Angular.js;jQuery;Laravel
#
#                               WebframeWorkedWith  \
# 0                                            NaN
# 1                                            NaN
# 2    ASP.NET Core;jQuery;Laravel;React.js;Vue.js
# 3                                            NaN
# 4                                          Flask
# ..                                           ...
# 995                  Angular;Angular.js;React.js
# 996                       Angular;Express;Spring
# 997                                          NaN
# 998                                          NaN
# 999            Angular;Angular.js;jQuery;Laravel
#
#                                 WelcomeChange WorkWeekHrs YearsCode  \
# 0     Just as welcome now as I felt last year        45.0        23
# 1     Just as welcome now as I felt last year        37.0        35
# 2       A lot less welcome now than last year        45.0         9
# 3    Somewhat less welcome now than last year        40.0        39
# 4     Just as welcome now as I felt last year        40.0        10
# ..                                        ...         ...       ...
# 995   Just as welcome now as I felt last year        40.0        10
# 996   Just as welcome now as I felt last year        50.0        41
# 997                                       NaN         NaN       NaN
# 998                                       NaN         NaN       NaN
# 999   Just as welcome now as I felt last year         8.0         8
#
#     YearsCodePro
# 0             15
# 1             22
# 2              5
# 3             29
# 4              3
# ..           ...
# 995            3
# 996           24
# 997          NaN
# 998          NaN
# 999            5
#
# [1000 rows x 61 columns]

# %%
survey_df['ConvertedComp'].count()  #not null
# Out:
# 517

# %%
survey_df['ConvertedComp'].median()
# Out:
# 48000.0

# %%
survey_df.median()
# Out:
# Respondent       32890.0
# Age                 29.0
# CompTotal        56000.0
# ConvertedComp    48000.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
survey_df.describe()
# Out:
#         Respondent         Age     CompTotal   ConvertedComp  WorkWeekHrs
# count   1000.00000  697.000000  5.170000e+02      517.000000   628.000000
# mean   33125.63900   30.810617  3.567064e+06    85067.394584    40.547771
# std    18973.33677    9.145613  5.058570e+07   142891.442494    13.103536
# min       59.00000   13.000000  1.000000e+00        0.000000     3.000000
# 25%    16665.25000   24.000000  1.500000e+04    19800.000000    40.000000
# 50%    32890.00000   29.000000  5.600000e+04    48000.000000    40.000000
# 75%    50005.25000   36.000000  1.200000e+05    88068.000000    44.000000
# max    65633.00000   67.000000  1.120000e+09  1000000.000000   160.000000

# %%
survey_df['OpSys'].value_counts(normalize=True)
# Out:
# Windows        0.481829
# Linux-based    0.282532
# MacOS          0.233294
# BSD            0.002345
# Name: OpSys, dtype: float64

# %%
survey_df['Country'].value_counts()
# Out:
# United States     182
# India             141
# Germany            55
# United Kingdom     52
# Brazil             36
#                  ...
# Uzbekistan          1
# Jordan              1
# Somalia             1
# Armenia             1
# Uruguay             1
# Name: Country, Length: 96, dtype: int64

# %%
country_groups = survey_df.groupby(['Country'])

# %%
country_groups.get_group('United States')
# Out:
#      Respondent                              MainBranch Hobbyist   Age  \
# 2         26082          I am a developer by profession      Yes  23.0
# 9         15003          I am a developer by profession      Yes  29.0
# 13        33014          I am a developer by profession      Yes  34.0
# 14        60030          I am a developer by profession      Yes  30.0
# 21         3363          I am a developer by profession       No  40.0
# ..          ...                                     ...      ...   ...
# 969       60882          I am a developer by profession       No  44.0
# 974       16427          I am a developer by profession      Yes  31.0
# 976       43500          I am a developer by profession      Yes  28.0
# 993        4528  I am a student who is learning to code      Yes  34.0
# 996       16771          I am a developer by profession      Yes   NaN
#
#     Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# 2           14   Yearly    65000.0        65000.0  United States
# 9           12   Yearly   115000.0       115000.0  United States
# 13          15   Yearly    81200.0        81200.0  United States
# 14          18   Yearly    90415.0        90415.0  United States
# 21          30   Yearly    76000.0        76000.0  United States
# ..         ...      ...        ...            ...            ...
# 969         10      NaN        NaN            NaN  United States
# 974         10   Yearly   220000.0       220000.0  United States
# 976         15      NaN        NaN            NaN  United States
# 993         10      NaN        NaN            NaN  United States
# 996         11      NaN        NaN            NaN  United States
#
#              CurrencyDesc  ...                  SurveyEase  \
# 2    United States dollar  ...                        Easy
# 9    United States dollar  ...                        Easy
# 13   United States dollar  ...                        Easy
# 14   United States dollar  ...                        Easy
# 21   United States dollar  ...                        Easy
# ..                    ...  ...                         ...
# 969  United States dollar  ...  Neither easy nor difficult
# 974  United States dollar  ...  Neither easy nor difficult
# 976  United States dollar  ...  Neither easy nor difficult
# 993                   NaN  ...                        Easy
# 996  United States dollar  ...                         NaN
#
#               SurveyLength Trans  \
# 2    Appropriate in length    No
# 9                 Too long    No
# 13   Appropriate in length    No
# 14   Appropriate in length    No
# 21               Too short    No
# ..                     ...   ...
# 969  Appropriate in length    No
# 974  Appropriate in length    No
# 976  Appropriate in length    No
# 993  Appropriate in length    No
# 996                    NaN   NaN
#
#                                         UndergradMajor  \
# 2    Computer science, computer engineering, or sof...
# 9    Computer science, computer engineering, or sof...
# 13                           Mathematics or statistics
# 14   Computer science, computer engineering, or sof...
# 21   Computer science, computer engineering, or sof...
# ..                                                 ...
# 969  Computer science, computer engineering, or sof...
# 974  Another engineering discipline (such as civil,...
# 976  Computer science, computer engineering, or sof...
# 993  Computer science, computer engineering, or sof...
# 996  Another engineering discipline (such as civil,...
#
#                 WebframeDesireNextYear  \
# 2                ASP.NET Core;React.js
# 9       Angular;Gatsby;React.js;Vue.js
# 13                                 NaN
# 14                    Express;React.js
# 21   Angular;Angular.js;ASP.NET;jQuery
# ..                                 ...
# 969                            Angular
# 974                ASP.NET Core;jQuery
# 976                                NaN
# 993              Django;Flask;React.js
# 996             Angular;Express;Spring
#
#                               WebframeWorkedWith  \
# 2    ASP.NET Core;jQuery;Laravel;React.js;Vue.js
# 9     Angular;Angular.js;Express;Gatsby;React.js
# 13                                           NaN
# 14                        Express;Flask;React.js
# 21                                ASP.NET;jQuery
# ..                                           ...
# 969                           Angular;Angular.js
# 974          Angular;ASP.NET;ASP.NET Core;jQuery
# 976                                          NaN
# 993                        Django;Flask;React.js
# 996                       Angular;Express;Spring
#
#                                WelcomeChange WorkWeekHrs YearsCode  \
# 2      A lot less welcome now than last year        45.0         9
# 9    Just as welcome now as I felt last year        40.0        13
# 13     A lot more welcome now than last year        40.0         6
# 14   Just as welcome now as I felt last year        40.0        11
# 21     A lot less welcome now than last year        40.0        10
# ..                                       ...         ...       ...
# 969  Just as welcome now as I felt last year        40.0        34
# 974  Just as welcome now as I felt last year        40.0        21
# 976  Just as welcome now as I felt last year        40.0        13
# 993  Just as welcome now as I felt last year         NaN        24
# 996  Just as welcome now as I felt last year        50.0        41
#
#     YearsCodePro
# 2              5
# 9             10
# 13             4
# 14             8
# 21             6
# ..           ...
# 969           22
# 974           11
# 976            6
# 993          NaN
# 996           24
#
# [182 rows x 61 columns]

# %%
country_filter = (survey_df['Country'] == 'China')
survey_df[country_filter]['OpSys'].value_counts()
# Out:
# Windows        3
# Linux-based    2
# MacOS          1
# Name: OpSys, dtype: int64

# %%
survey_df.groupby(['Country'])['OpSys'].value_counts()
# Out:
# Country                               OpSys
# Albania                               Windows        2
# Algeria                               Linux-based    1
#                                       Windows        1
# Argentina                             Linux-based    2
#                                       MacOS          1
#                                                     ..
# Uzbekistan                            Windows        1
# Venezuela, Bolivarian Republic of...  Linux-based    1
# Viet Nam                              Linux-based    1
#                                       Windows        1
# Zambia                                Linux-based    1
# Name: OpSys, Length: 179, dtype: int64

# %%
country_groups['OpSys'].value_counts().loc['China']
# Out:
# OpSys
# Windows        3
# Linux-based    2
# MacOS          1
# Name: OpSys, dtype: int64

# %%
country_groups['ConvertedComp'].median()
# Out:
# Country
# Albania                                 18546.0
# Algeria                                     NaN
# Angola                                      NaN
# Argentina                               11676.0
# Armenia                                 66000.0
#                                          ...
# Uruguay                                     NaN
# Uzbekistan                                  NaN
# Venezuela, Bolivarian Republic of...    12000.0
# Viet Nam                                 9600.0
# Zambia                                      NaN
# Name: ConvertedComp, Length: 96, dtype: float64

# %%
country_groups['ConvertedComp'].median().loc['Germany']
# Out:
# 61105.0

# %%
country_groups['ConvertedComp'].agg(['median','mean'])
# Out:
#                                        median     mean
# Country
# Albania                               18546.0  18546.0
# Algeria                                   NaN      NaN
# Angola                                    NaN      NaN
# Argentina                             11676.0  19072.8
# Armenia                               66000.0  66000.0
# ...                                       ...      ...
# Uruguay                                   NaN      NaN
# Uzbekistan                                NaN      NaN
# Venezuela, Bolivarian Republic of...  12000.0  12000.0
# Viet Nam                               9600.0   9600.0
# Zambia                                    NaN      NaN
#
# [96 rows x 2 columns]
